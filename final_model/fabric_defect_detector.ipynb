# %%
from roboflow import Roboflow
rf = Roboflow(api_key="mtMsND6Fll56Xm7DnWu0")
project = rf.workspace("sailappan-sn6vd").project("tilda-fabric-ujur1")
version = project.version(1)
dataset = version.download("yolov8")

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

# %%
model.train(
    data='TILDA-Fabric-1/data.yaml', 
    epochs=100, 
    imgsz=640, 
    batch=16,
    optimizer='AdamW', # Good for industrial datasets
    name='fabric_defect_model'
)

# %%
# Load your previous best to start with "Transfer Learning"
from ultralytics import YOLO
model = YOLO(r'C:\Users\Sailappan\Desktop\Liveness\runs\detect\fabric_defect_model9\weights\best.pt')

# %%
model.train(
    data='TILDA-Fabric-1/data.yaml', 
    epochs=300, 
    imgsz=640, 
    batch=16, 
    patience=50,
    optimizer='AdamW',
    device=0
    )
# Out:
# Ultralytics 8.4.12  Python-3.10.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...
