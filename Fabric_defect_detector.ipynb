# %%
from roboflow import Roboflow
rf = Roboflow(api_key="mtMsND6Fll56Xm7DnWu0")
project = rf.workspace("sailappan-sn6vd").project("aitex-textile-defects-v2-9gyiw")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import os
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
results = model.train(
    data="aitex-textile-defects-v2-1/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    optimizer='AdamW',
    lr0=0.001,
    project='fabric_final',
    name='monochrome_run_fixed'
)
# Out:
# Ultralytics 8.4.12  Python-3.10.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...

# %%
results = model.train(
    data="aitex-textile-defects-v2-1/data.yaml",
    epochs=300,
    patience=20,
    imgsz=640,
    batch=16,
    optimizer='AdamW',
    lr0=0.001,
    project='fabric_final',
    name='high_epoch_run',
    device = 0
)
# Out:
# Ultralytics 8.4.12  Python-3.10.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...
